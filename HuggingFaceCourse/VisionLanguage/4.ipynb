# %% [markdown]
# <a href="https://colab.research.google.com/github/emanhassan2020/LLM/blob/main/HuggingFaceCourse/VisionLanguage/4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hands-On Exercises: Fine-Tuning SmolVLM2-2.2B-Instruct

# %% [markdown]
# Welcome to the practical section! Here you'll put into practice everything you've learned about vision language models (VLMs) using **HuggingFaceTB/SmolVLM2-2.2B-Instruct**.
# The exercises progress from foundational concepts to advanced techniques, helping you gain real-world, hands-on experience.

# %% [markdown]
# ## Learning Objectives
#
# By the end of these exercises, you will be able to:
#
# - **Work with VLM datasets**: Explore and prepare **HuggingFaceM4/ChartQA**.
# - **Optimize training**: Apply **quantization** and **PEFT** for efficient fine-tuning.
# - **Fine-tune models in practice**: Train **HuggingFaceTB/SmolVLM2-2.2B-Instruct** using both Python APIs and CLI tools.
# - **Adapt datasets for TRL**: Prepare VLM datasets to integrate seamlessly with TRL workflows.
# - **Move to production**: Understand how to scale and manage **production-ready fine-tuning workflows** for VLMs.

# %% [markdown]
# ## Exercise 1: Explore `SmolVLM2-2.2B-Instruct`
#
# **Objective:** Get familiar with the `SmolVLM2-2.2B-Instruct` model and evaluate the model using a sample from the dataset.
#
# ### Environment Setup
#
# <Tip warning={true}>
#
# - You need a GPU with at least 8GB VRAM for training. CPU/MPS can run formatting and dataset exploration, but training larger models will likely fail.
# - First run will download several GB of model weights; ensure 15GB+ free disk and a stable connection.
# - If you need access to private repos, authenticate with Hugging Face Hub via `login()`.
#
# </Tip>
#
# First, install the required libraries: `transformers`, `datasets`, `trl`,`huggingface_hub`, and `trackio`.
# These packages provide the tools for working with the model, datasets, and Hugging Face Hub.

# %%
# Install required packages (run in Colab or your environment)
# !pip install transformers datasets trl huggingface_hub trackio num2words==0.5.14
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.13/dist-packages (5.16.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.13/dist-packages (4.0.0)
# Collecting trl
#   Downloading trl-1.12.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.13/dist-packages (1.28.0)
# Collecting trackio
#   Downloading trackio-0.37.0-py3-none-any.whl.metadata (20 kB)
# Collecting num2words==0.5.14
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Collecting docopt>=0.6.2 (from num2words==0.5.14)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.13/dist-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from transformers) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.13/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<0.24.0,>=0.23.1 in /usr/local/lib/python3.13/dist-packages (from transformers) (0.23.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from transformers) (0.27.1)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.13/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets) (3.32.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.13/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.13/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: accelerate>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from trl) (1.14.0)
# Collecting datasets
#   Downloading datasets-5.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from trl) (3.1.6)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-25.0.1-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub) (4.16.0)
# Requirement already satisfied: brotli<2.0.0,>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from trackio) (1.2.0)
# Requirement already satisfied: gradio-client<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from trackio) (2.6.1)
# Requirement already satisfied: orjson<4.0.0,>=3.0 in /usr/local/lib/python3.13/dist-packages (from trackio) (3.12.0)
# Requirement already satisfied: pillow<13.0.0 in /usr/local/lib/python3.13/dist-packages (from trackio) (11.3.0)
# Requirement already satisfied: python-multipart<1.0.0,>=0.0.9 in /usr/local/lib/python3.13/dist-packages (from trackio) (0.0.32)
# Requirement already satisfied: starlette<2.0.0 in /usr/local/lib/python3.13/dist-packages (from trackio) (1.6.0)
# Requirement already satisfied: uvicorn<1.0.0,>=0.30.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]<1.0.0,>=0.30.0->trackio) (0.52.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (5.9.5)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from accelerate>=1.4.0->trl) (2.11.0+cu128)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]<1.0.0,>=0.30.0->trackio) (0.8.0)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]<1.0.0,>=0.30.0->trackio) (1.2.3)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]<1.0.0,>=0.30.0->trackio) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]<1.0.0,>=0.30.0->trackio) (1.2.0)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]<1.0.0,>=0.30.0->trackio) (15.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->trl) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets) (2026.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->transformers) (0.0.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.24.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers) (2.21.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.6.1)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->accelerate>=1.4.0->trl) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->accelerate>=1.4.0->trl) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->accelerate>=1.4.0->trl) (1.7.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate>=1.4.0->trl) (1.3.0)
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 5.9 MB/s eta 0:00:00
# Downloading trl-1.12.0-py3-none-any.whl (992 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.6/992.6 kB 28.1 MB/s eta 0:00:00
# Downloading datasets-5.0.1-py3-none-any.whl (559 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.1/559.1 kB 48.3 MB/s eta 0:00:00
# Downloading trackio-0.37.0-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 98.1 MB/s eta 0:00:00
# Downloading pyarrow-25.0.1-cp313-cp313-manylinux_2_28_x86_64.whl (50.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 51.0 MB/s eta 0:00:00
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=743039c42af3c2c40aa9e25d19d24e50630987a6ab5a4f4d231c799ba8b80c16
#   Stored in directory: /root/.cache/pip/wheels/0b/1d/03/175286677fb5a1341cc3e4755bf8ec0ed08f3329afd67446b0
# Successfully built docopt
# Installing collected packages: docopt, pyarrow, num2words, datasets, trackio, trl
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# Successfully installed datasets-5.0.1 docopt-0.6.2 num2words-0.5.14 pyarrow-25.0.1 trackio-0.37.0 trl-1.12.0

# %% [markdown]
# ### Import dependencies
#
# Now, import the main dependencies we'll use:

# %%
# Import dependencies

import torch
import os
from transformers import AutoProcessor, AutoModelForImageTextToText, BitsAndBytesConfig
from transformers.image_utils import load_image

# %% [markdown]
# ### Load the model and processor
#
# #### 1. Select the device
#
# We start by selecting the device where the model will run. It can be a GPU (`cuda`), Apple Silicon (`mps`), or the CPU as a fallback.

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)

# %% [markdown]
# #### 2. Authenticate with Hugging Face
#
# To work with private models or to **push your fine-tuned model to the Hub** (as we'll do in this exercise), you need to authenticate with your Hugging Face account.
#
# <Tip>
#
# You can create and copy your access token from the [Hugging Face tokens page](https://huggingface.co/settings/tokens) in your profile.
#
# </Tip>

# %%
from huggingface_hub import login
login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>A19C-I4TB</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center>Login successful. Logged in as <b>EmanHassan26</b> (token: <code>oauth-EmanHassan26</code>).<br>This token will be refreshed automatically when it expires.</center>

# %% [markdown]
# #### 3. Load the model and processor
#
# Finally, we load the **HuggingFaceTB/SmolVLM2-2.2B-Instruct** model.
# The `AutoProcessor` is also initialized here — it ensures that both text and images are preprocessed correctly before being passed to the model.

# %%
model_name = "HuggingFaceTB/SmolVLM2-2.2B-Instruct"
model = AutoModelForImageTextToText.from_pretrained(
    model_name,
    dtype=torch.bfloat16,
).to(device)

processor = AutoProcessor.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/3.64k [00:00<?, ?B/s]
# [transformers] Model config: pad_token_id must be `None` or an integer within the vocabulary (between 0 and 31999), got 128002. This may result in unexpected behavior.
# model.safetensors.index.json:   0%|          | 0.00/63.9k [00:00<?, ?B/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/657 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/136 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/430 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/28.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.55M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/4.74k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/868 [00:00<?, ?B/s]

# %% [markdown]
# ### Explore the dataset
#
# In this step, we load a small subset of the **ChartQA** dataset — just 10% of the training and validation splits — to keep the exercises fast and manageable for learning purposes.
#
# We then display one of the chart images using `matplotlib` to get a visual sense of the model's input.
# Additionally, we print the corresponding query and label so you can fully understand the dataset structure and the type of tasks the model will handle.

# %%
from IPython.display import IFrame

IFrame(
    src="https://huggingface.co/datasets/HuggingFaceM4/ChartQA/embed/viewer/default/train",
    width="100%",
    height=560
)
# Out:
#         <iframe
#             width="100%"
#             height="560"
#             src="https://huggingface.co/datasets/HuggingFaceM4/ChartQA/embed/viewer/default/train"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from datasets import load_dataset
import matplotlib.pyplot as plt

train_dataset, eval_dataset = load_dataset("HuggingFaceM4/ChartQA", split=["train[:10%]", "val[:10%]"])
example = train_dataset[1]
image = load_image(example["image"])

print(example["query"])
print(example["label"][0])
# Out:
# README.md:   0%|          | 0.00/852 [00:00<?, ?B/s]
# data/train-00000-of-00003-49492f364babfa(…): reconstructing file:   0%|          |  0.00B /  219MB
# data/train-00000-of-00003-49492f364babfa(…): downloading bytes:           |  0.00B
# data/train-00001-of-00003-7302bae5e425bb(…): reconstructing file:   0%|          |  0.00B /  311MB
# data/train-00001-of-00003-7302bae5e425bb(…): downloading bytes:           |  0.00B
# data/train-00002-of-00003-194c9400785577(…): reconstructing file:   0%|          |  0.00B /  315MB
# data/train-00002-of-00003-194c9400785577(…): downloading bytes:           |  0.00B
# data/val-00000-of-00001-0f11003c77497969(…): reconstructing file:   0%|          |  0.00B / 50.2MB
# data/val-00000-of-00001-0f11003c77497969(…): downloading bytes:           |  0.00B
# data/test-00000-of-00001-e2cd0b7a0f9eb20(…): reconstructing file:   0%|          |  0.00B / 68.9MB
# data/test-00000-of-00001-e2cd0b7a0f9eb20(…): downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/28299 [00:00<?, ? examples/s]
# Generating val split:   0%|          | 0/1920 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2500 [00:00<?, ? examples/s]
# How many values are below 40 in Unfavorable graph?
# 6

# %%
plt.imshow(image)
plt.axis("off")
plt.title("Sample Chart Image")
plt.show()

# %% [markdown]
# ### Build a chat-style prompt
#
# We create a **chat message list** that includes a user query along with the image.
#
# Using `processor.apply_chat_template`, we transform this into the exact input format the model expects.

# %%
# Define a chat-style prompt
messages = [
    {"role": "user", "content": [
        {"type": "image", "image": image},
        {"type": "text", "text": example["query"]},
    ]}
]

# Apply the chat template
chat_prompt = processor.apply_chat_template(
      messages, add_generation_prompt=True\
)
print(chat_prompt)
# Out:
# [transformers] Kwargs passed to `processor.__call__` have to be in `processor_kwargs` dict, not in `**kwargs`
# <|im_start|>User:How many values are below 40 in Unfavorable graph?<end_of_utterance>
# Assistant:

# %% [markdown]
# ### Run inference
#
# We tokenize the chat prompt and image into tensors, then generate a response with the model.
# Finally, we decode the output tokens back into text.

# %%
# Tokenize input
inputs = processor(images=[image], text=chat_prompt, return_tensors="pt").to(device)

# Generate model output
with torch.no_grad():
    output = model.generate(**inputs, max_new_tokens=20)

# Trim the generated ids to remove the input ids
trimmed_generated_ids = [out_ids[len(in_ids) :] for in_ids, out_ids in zip(inputs.input_ids, output)]

# Decode the output text
output_text = processor.batch_decode(
    trimmed_generated_ids, skip_special_tokens=True, clean_up_tokenization_spaces=False
)
print(output_text)
# Out:
# [' 6.']

# %% [markdown]
# The model generates a reponse, but it's not exactly correct. It could be improved with some fine-tuning. Now that we've seen how to build prompts and generate responses with **SmolVLM2-2.2B-Instruct**, it's time to learn how to adapt and **fine-tune** the model efficiently using **LoRA (Low-Rank Adaptation)**. This approach allows training large models with fewer resources and prepares the model for specific downstream tasks.
#
#
# ## Exercise 2: Fine-Tune the Model Using LoRA
#
# In this exercise, we'll apply **LoRA (Low-Rank Adaptation)** to fine-tune our Vision-Language Model efficiently.
#
# LoRA works by injecting **trainable low-rank matrices** into existing model layers, enabling **large models to be fine-tuned with significantly fewer trainable parameters**.
# This approach reduces memory usage and speeds up training while maintaining high performance.

# %% [markdown]
# ### Format dataset
#
# The first step involves formatting the dataset for VLM training. We'll create a system message to make the VLM act as a chart analysis expert, giving concise answers about chart images.

# %%
system_message = """You are a Vision Language Model specialized in interpreting visual data from chart images.
Your task is to analyze the provided chart image and respond to queries with concise answers, usually a single word, number, or short phrase.
The charts include a variety of types (e.g., line charts, bar charts) and contain colors, labels, and text.
Focus on delivering accurate, succinct answers based on the visual information. Avoid additional explanation unless absolutely necessary."""

# %% [markdown]
# We'll format the dataset into a chatbot structure, with the system message, image, user query, and answer for each interaction. This dataset format is expect by the `SFTTrainer`, includind the `images` and `messages` columns. You can learn more about formatting the datasets for VLM post training in the [docs](https://huggingface.co/docs/trl/en/sft_trainer#training-vision-language-models).

# %%
def format_data(sample):
    return {
        "images": [sample["image"]],
        "messages": [
            {
                "role": "system",
                "content": [{"type": "text", "text": system_message}],
            },
            {
                "role": "user",
                "content": [
                    {
                        "type": "image",
                        "image": sample["image"],
                    },
                    {
                        "type": "text",
                        "text": sample["query"],
                    },
                ],
            },
            {
                "role": "assistant",
                "content": [{"type": "text", "text": sample["label"][0]}],
            },
        ],
    }

# %% [markdown]
# Now, let’s format the data using the chatbot structure. This will set up the interactions for the model.

# %%
train_dataset = [format_data(sample) for sample in train_dataset]
eval_dataset = [format_data(sample) for sample in eval_dataset]

# %% [markdown]
# ### Configure LoRA
#
# Here we define a `LoraConfig`:
# - `r` and `lora_alpha` control the rank and scaling of the adaptation matrices.
# - `target_modules` specifies which parts of the model to adapt.
# - `task_type` is set for causal language modeling.
#
# We then apply LoRA to the base model using `get_peft_model` and print out the trainable parameters to verify the adaptation.

# %%
import warnings
warnings.filterwarnings('ignore') # Ignore warnings from torchao for now

# !pip install --upgrade torchao

from peft import LoraConfig, get_peft_model

# Configure LoRA
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.05,
    r=8,
    target_modules=["q_proj", "v_proj"],
    task_type="CAUSAL_LM",
)

# Apply PEFT model adaptation
peft_model = get_peft_model(model, peft_config)

# Print trainable parameters
peft_model.print_trainable_parameters()
# Out:
# Requirement already satisfied: torchao in /usr/local/lib/python3.13/dist-packages (0.10.0)
# Collecting torchao
#   Downloading torchao-0.18.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (21 kB)
# Downloading torchao-0.18.0-cp310-abi3-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 38.5 MB/s eta 0:00:00
# Installing collected packages: torchao
#   Attempting uninstall: torchao
#     Found existing installation: torchao 0.10.0
#     Uninstalling torchao-0.10.0:
#       Successfully uninstalled torchao-0.10.0
# Successfully installed torchao-0.18.0
# WARNING:torchao:Failed to load /usr/local/lib/python3.13/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.13/dist-packages/torchao/_C_cutlass_90a.abi3.so
# WARNING:torchao:Failed to load /usr/local/lib/python3.13/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.13/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# trainable params: 2,568,192 || all params: 2,249,353,072 || trainable%: 0.1142

# %% [markdown]
# ### Set up the Trainer
#
# We configure the **SFTTrainer** from `trl` with `SFTConfig`:
# - `num_train_epochs`, `batch_size`, and `gradient_accumulation_steps` control the training loop.
# - `gradient_checkpointing`, and `bf16` optimize memory and speed.
# - `learning_rate` manages optimization.
# - `train_dataset` and `eval_dataset` are aligned with your dataset.
#
# This prepares the trainer to handle fine-tuning with PEFT/LoRA.

# %%
from trl import SFTConfig, SFTTrainer
from datasets import Dataset # Import Dataset class

# Configure training arguments using SFTConfig
training_args = SFTConfig(
    output_dir="smol-course-SmolVLM2-2.2B-Instruct-trl-sft-ChartQA",
    num_train_epochs=1,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=4,
    learning_rate=1e-4,
    logging_steps=25,
    save_strategy="steps",
    save_steps=25,
    optim="adamw_torch_fused",
    bf16=True,
    push_to_hub=True,
    report_to="trackio",
    max_length=None,
)

# Convert the lists of dictionaries back to Dataset objects
train_dataset = Dataset.from_list(train_dataset)
eval_dataset = Dataset.from_list(eval_dataset)

# Initialize the Trainer
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    peft_config=peft_config,
)

# Align the SFTTrainer params with your chosen dataset.

# %% [markdown]
# ### Train and Save the Model
#
# Now we run the training loop:
# 1. `trainer.train()` starts fine-tuning with LoRA.
# 2. `trainer.save_model()` stores the locally trained model.
#
# This step ensures the model is ready for downstream tasks with minimal additional parameters.

# %%
from datasets import Dataset
from trl import SFTTrainer, SFTConfig

# Define a function to correct the messages structure within each sample
def _correct_messages_format_for_sfttrainer(sample):
    corrected_messages = []
    for msg in sample["messages"]:
        if msg["role"] == "user":
            # Original user content was a list like:
            # [{'type': 'image', 'image': PIL_Image_Object}, {'type': 'text', 'text': 'query_text'}]
            # We need to transform it into a single string: "query_text"
            user_text_content = ""
            for part in msg["content"]:
                if part["type"] == "text":
                    user_text_content = part["text"]
                    break
            corrected_messages.append(
                {
                    "role": "user",
                    "content": "" + user_text_content
                }
            )
        elif msg["role"] == "system" or msg["role"] == "assistant":
            # Original content was a list like: [{'type': 'text', 'text': 'some_text'}]
            # We need to extract just the string 'some_text'
            corrected_messages.append(
                {
                    "role": msg["role"],
                    "content": msg["content"][0]["text"]
                }
            )
        else:
            corrected_messages.append(msg) # Keep other roles as is, though unlikely

    sample["messages"] = corrected_messages
    return sample

# Apply the correction to the existing train_dataset and eval_dataset
# These datasets are already defined in the global scope from previous cells.
# They are datasets.Dataset objects.
corrected_train_dataset = train_dataset.map(_correct_messages_format_for_sfttrainer)
corrected_eval_dataset = eval_dataset.map(_correct_messages_format_for_sfttrainer)

# Re-initialize the Trainer with the corrected datasets
# The variables model, training_args, peft_config should be available in the global scope
trainer = SFTTrainer(
    model=model,
    args=training_args,
    train_dataset=corrected_train_dataset,
    eval_dataset=corrected_eval_dataset,
    peft_config=peft_config,
)

# Train the model
trainer.train()

# Save the model
trainer.save_model(training_args.output_dir)
# Out:
# Map:   0%|          | 0/2830 [00:00<?, ? examples/s]
# Map:   0%|          | 0/192 [00:00<?, ? examples/s]
# [transformers] Kwargs passed to `processor.__call__` have to be in `processor_kwargs` dict, not in `**kwargs`
# * Run finished. Uploading logs to Trackio (please wait...)
# * Created new run: dainty-sunset-0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1703/2403776447.py in <cell line: 0>()
#      53
#      54 # Train the model
# ---> 55 trainer.train()
#      56
#      57 # Save the model
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1456         ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1457         with ctx:
# -> 1458             return inner_training_loop(
#    1459                 args=args,
#    1460                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1538         for epoch in range(epochs_trained, num_train_epochs):
#    1539             self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1540             self._run_epoch(
#    1541                 model=model,
#    1542                 epoch=epoch,
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in _run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1733                 self.args.gradient_accumulation_steps if update_step != (num_update_steps_per_epoch - 1) else remainder
#    1734             )
# -> 1735             batch_samples, num_items_in_batch = self.get_batch_samples(epoch_iterator, num_batches, self.args.device)
#    1736
#    1737             # This is used to correctly scale the loss when the last accumulation step has fewer batches.
#
# /usr/local/lib/python3.13/dist-packages/transformers/trainer.py in get_batch_samples(self, epoch_iterator, num_batches, device)
#    2141         for _ in range(num_batches):
#    2142             try:
# -> 2143                 batch_samples.append(next(epoch_iterator))
#    2144             except StopIteration:
#    2145                 break
#
# /usr/local/lib/python3.13/dist-packages/accelerate/data_loader.py in __iter__(self)
#     583         # We iterate one batch ahead to check when we are at the end
#     584         try:
# --> 585             current_batch = next(dataloader_iter)
#     586         except StopIteration:
#     587             self.end()
#
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     739                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740                 self._reset()  # type: ignore[call-arg]
# --> 741             data = self._next_data()
#     742             self._num_yielded += 1
#     743             if (
#
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     799     def _next_data(self):
#     800         index = self._next_index()  # may raise StopIteration
# --> 801         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802         if self._pin_memory:
#     803             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.13/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      55         else:
#      56             data = self.dataset[possibly_batched_index]
# ---> 57         return self.collate_fn(data)
#
# /usr/local/lib/python3.13/dist-packages/transformers/data/data_collator.py in __call__(self, features, return_tensors)
#      40             return_tensors = self.return_tensors
#      41         if return_tensors == "pt":
# ---> 42             return self.torch_call(features)
#      43         elif return_tensors == "np":
#      44             return self.numpy_call(features)
#
# /usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py in torch_call(self, examples)
#     643                     "The `completion_only_loss` argument is not supported for language modeling datasets."
#     644                 )
# --> 645             return self._collate_language_modeling(examples)
#     646         elif "prompt" in examples[0] and "completion" in examples[0]:
#     647             return self._collate_prompt_completion(examples)
#
# /usr/local/lib/python3.13/dist-packages/trl/trainer/sft_trainer.py in _collate_language_modeling(self, examples)
#     671             )
#     672
# --> 673         output = self.processor(
#     674             images=images,
#     675             text=texts,
#
# /usr/local/lib/python3.13/dist-packages/transformers/processing_utils.py in __call__(self, images, text, videos, audio, **kwargs)
#     665             images=images, text=text, videos=videos, audio=audio, **kwargs
#     666         )
# --> 667         self.validate_inputs(images=images, text=text, videos=videos, audio=audio, **kwargs)
#     668
#     669         merged_kwargs = self._merge_kwargs(
#
# /usr/local/lib/python3.13/dist-packages/transformers/models/smolvlm/processing_smolvlm.py in validate_inputs(self, images, text, videos, **kwargs)
#     161                 n_images_in_images = [len(sublist) for sublist in images]
#     162                 if n_images_in_images != n_images_per_sample:
# --> 163                     raise ValueError(
#     164                         f"The number of images in the text {n_images_per_sample} and images {n_images_in_images} should be the same."
#     165                     )
#
# ValueError: The number of images in the text [2, 2, 2, 2] and images [1, 1, 1, 1] should be the same.
